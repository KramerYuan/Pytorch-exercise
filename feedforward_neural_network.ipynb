# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters 
input_size = 784
hidden_size = 500
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
# Fully connected neural network with one hidden layer
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)  
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  

# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # Move tensors to the configured device
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# Out:
# Epoch [1/5], Step [100/600], Loss: 0.4387
# Epoch [1/5], Step [200/600], Loss: 0.4074
# Epoch [1/5], Step [300/600], Loss: 0.2194
# Epoch [1/5], Step [400/600], Loss: 0.2168
# Epoch [1/5], Step [500/600], Loss: 0.1574
# Epoch [1/5], Step [600/600], Loss: 0.1616
# Epoch [2/5], Step [100/600], Loss: 0.1177
# Epoch [2/5], Step [200/600], Loss: 0.1247
# Epoch [2/5], Step [300/600], Loss: 0.0682
# Epoch [2/5], Step [400/600], Loss: 0.2041
# Epoch [2/5], Step [500/600], Loss: 0.0859
# Epoch [2/5], Step [600/600], Loss: 0.0525
# Epoch [3/5], Step [100/600], Loss: 0.0557
# Epoch [3/5], Step [200/600], Loss: 0.0493
# Epoch [3/5], Step [300/600], Loss: 0.0594
# Epoch [3/5], Step [400/600], Loss: 0.0571
# Epoch [3/5], Step [500/600], Loss: 0.0790
# Epoch [3/5], Step [600/600], Loss: 0.0411
# Epoch [4/5], Step [100/600], Loss: 0.0309
# Epoch [4/5], Step [200/600], Loss: 0.0432
# Epoch [4/5], Step [300/600], Loss: 0.0983
# Epoch [4/5], Step [400/600], Loss: 0.0476
# Epoch [4/5], Step [500/600], Loss: 0.0318
# Epoch [4/5], Step [600/600], Loss: 0.0064
# Epoch [5/5], Step [100/600], Loss: 0.0171
# Epoch [5/5], Step [200/600], Loss: 0.0156
# Epoch [5/5], Step [300/600], Loss: 0.0477
# Epoch [5/5], Step [400/600], Loss: 0.0989
# Epoch [5/5], Step [500/600], Loss: 0.1280
# Epoch [5/5], Step [600/600], Loss: 0.0455

# %%
correct = 0
total = 0
for images, labels in test_loader:
    images = images.reshape(-1, 28*28).to(device)
    labels = labels.to(device)
    outputs = model(images)
    _,predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()
    
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 100.0 %
# Accuracy of the network on the 10000 test images: 99.5 %
# Accuracy of the network on the 10000 test images: 99.33333333333333 %
# Accuracy of the network on the 10000 test images: 99.0 %
# Accuracy of the network on the 10000 test images: 98.8 %
# Accuracy of the network on the 10000 test images: 98.66666666666667 %
# Accuracy of the network on the 10000 test images: 98.42857142857143 %
# Accuracy of the network on the 10000 test images: 98.25 %
# Accuracy of the network on the 10000 test images: 98.33333333333333 %
# Accuracy of the network on the 10000 test images: 98.1 %
# Accuracy of the network on the 10000 test images: 98.0 %
# Accuracy of the network on the 10000 test images: 97.83333333333333 %
# Accuracy of the network on the 10000 test images: 97.61538461538461 %
# Accuracy of the network on the 10000 test images: 97.42857142857143 %
# Accuracy of the network on the 10000 test images: 97.6 %
# Accuracy of the network on the 10000 test images: 97.375 %
# Accuracy of the network on the 10000 test images: 97.23529411764706 %
# Accuracy of the network on the 10000 test images: 97.11111111111111 %
# Accuracy of the network on the 10000 test images: 97.21052631578948 %
# Accuracy of the network on the 10000 test images: 97.2 %
# Accuracy of the network on the 10000 test images: 97.04761904761905 %
# Accuracy of the network on the 10000 test images: 96.81818181818181 %
# Accuracy of the network on the 10000 test images: 96.78260869565217 %
# Accuracy of the network on the 10000 test images: 96.83333333333333 %
# Accuracy of the network on the 10000 test images: 96.8 %
# Accuracy of the network on the 10000 test images: 96.88461538461539 %
# Accuracy of the network on the 10000 test images: 96.88888888888889 %
# Accuracy of the network on the 10000 test images: 97.0 %
# Accuracy of the network on the 10000 test images: 97.0 %
# Accuracy of the network on the 10000 test images: 96.93333333333334 %
# Accuracy of the network on the 10000 test images: 96.90322580645162 %
# Accuracy of the network on the 10000 test images: 96.96875 %
# Accuracy of the network on the 10000 test images: 97.06060606060606 %
# Accuracy of the network on the 10000 test images: 97.11764705882354 %
# Accuracy of the network on the 10000 test images: 97.11428571428571 %
# Accuracy of the network on the 10000 test images: 97.0 %
# Accuracy of the network on the 10000 test images: 97.05405405405405 %
# Accuracy of the network on the 10000 test images: 97.05263157894737 %
# Accuracy of the network on the 10000 test images: 97.02564102564102 %
# Accuracy of the network on the 10000 test images: 96.975 %
# Accuracy of the network on the 10000 test images: 97.0 %
# Accuracy of the network on the 10000 test images: 97.02380952380952 %
# Accuracy of the network on the 10000 test images: 97.02325581395348 %
# Accuracy of the network on the 10000 test images: 97.04545454545455 %
# Accuracy of the network on the 10000 test images: 97.08888888888889 %
# Accuracy of the network on the 10000 test images: 97.08695652173913 %
# Accuracy of the network on the 10000 test images: 97.12765957446808 %
# Accuracy of the network on the 10000 test images: 97.14583333333333 %
# Accuracy of the network on the 10000 test images: 97.12244897959184 %
# Accuracy of the network on the 10000 test images: 97.14 %
# Accuracy of the network on the 10000 test images: 97.19607843137256 %
# Accuracy of the network on the 10000 test images: 97.25 %
# Accuracy of the network on the 10000 test images: 97.30188679245283 %
# Accuracy of the network on the 10000 test images: 97.33333333333333 %
# Accuracy of the network on the 10000 test images: 97.36363636363636 %
# Accuracy of the network on the 10000 test images: 97.41071428571429 %
# Accuracy of the network on the 10000 test images: 97.40350877192982 %
# Accuracy of the network on the 10000 test images: 97.41379310344827 %
# Accuracy of the network on the 10000 test images: 97.42372881355932 %
# Accuracy of the network on the 10000 test images: 97.31666666666666 %
# Accuracy of the network on the 10000 test images: 97.27868852459017 %
# Accuracy of the network on the 10000 test images: 97.30645161290323 %
# Accuracy of the network on the 10000 test images: 97.34920634920636 %
# Accuracy of the network on the 10000 test images: 97.390625 %
# Accuracy of the network on the 10000 test images: 97.43076923076923 %
# Accuracy of the network on the 10000 test images: 97.36363636363636 %
# Accuracy of the network on the 10000 test images: 97.38805970149254 %
# Accuracy of the network on the 10000 test images: 97.38235294117646 %
# Accuracy of the network on the 10000 test images: 97.40579710144928 %
# Accuracy of the network on the 10000 test images: 97.44285714285714 %
# Accuracy of the network on the 10000 test images: 97.47887323943662 %
# Accuracy of the network on the 10000 test images: 97.51388888888889 %
# Accuracy of the network on the 10000 test images: 97.54794520547945 %
# Accuracy of the network on the 10000 test images: 97.58108108108108 %
# Accuracy of the network on the 10000 test images: 97.6 %
# Accuracy of the network on the 10000 test images: 97.63157894736842 %
# Accuracy of the network on the 10000 test images: 97.66233766233766 %
# Accuracy of the network on the 10000 test images: 97.6923076923077 %
# Accuracy of the network on the 10000 test images: 97.72151898734177 %
# Accuracy of the network on the 10000 test images: 97.725 %
# Accuracy of the network on the 10000 test images: 97.70370370370371 %
# Accuracy of the network on the 10000 test images: 97.73170731707317 %
# Accuracy of the network on the 10000 test images: 97.74698795180723 %
# Accuracy of the network on the 10000 test images: 97.76190476190476 %
# Accuracy of the network on the 10000 test images: 97.78823529411764 %
# Accuracy of the network on the 10000 test images: 97.76744186046511 %
# Accuracy of the network on the 10000 test images: 97.79310344827586 %
# Accuracy of the network on the 10000 test images: 97.81818181818181 %
# Accuracy of the network on the 10000 test images: 97.84269662921348 %
# Accuracy of the network on the 10000 test images: 97.86666666666666 %
# Accuracy of the network on the 10000 test images: 97.84615384615384 %
# Accuracy of the network on the 10000 test images: 97.8695652173913 %
# Accuracy of the network on the 10000 test images: 97.89247311827957 %
# Accuracy of the network on the 10000 test images: 97.91489361702128 %
# Accuracy of the network on the 10000 test images: 97.93684210526315 %
# Accuracy of the network on the 10000 test images: 97.94791666666667 %
# Accuracy of the network on the 10000 test images: 97.91752577319588 %
# Accuracy of the network on the 10000 test images: 97.86734693877551 %
# Accuracy of the network on the 10000 test images: 97.86868686868686 %
# Accuracy of the network on the 10000 test images: 97.86 %
